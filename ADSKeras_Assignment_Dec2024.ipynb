# %% [markdown]
# # CW1 - Multimodal IMDB Analysis with Keras
#
# ## Introduction
#
# In this assignment you will be provided a dataset containing a selection of films together with their posters in JPEG image format and their overviews in text format from the Internet Movie Database.
#
# ![Example](https://i.ibb.co/J3trT62/Screenshot-2024-09-22-214753.png)
#
# You will be analysing this dataset by implementing and training two models: a **CNN** and an **LSTM**.
#
# The CNN must classify film posters by the genre. Independently, the LSTM must classify film overviews by the genre. Finally, you will evaluate and critically comment your results in a short report. (Which of the two models was better at classifying films?)
#
# ## Structure of the assignment
#
# This assignment is broken up into sections and you need to complete each section successively. The sections are the following:
#
# 1. Data Processing
#
#   1.a. Image processing of the posters
#
#   1.b. Natural language processing of the overviews
#
# 2. Definition of the models
#
#   2.a. CNN for the posters
#
#   2.b. LSTM for the overviews
#
# 3. Training of the models
# 4. Evaluation of the models
#
# In addition to this coding exercise, you must write a **2-3 pages** report analysing and critically evaluating your model's results. Marks for the report will be awarded for depth of analysis and critical thinking skills. You should consider how well your model performs and WHY it does that—give specific examples and comment on their importance.

# %%
# Enter your module imports here, some modules are already provided

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import os
import pathlib
import pandas as pd
from sklearn import model_selection
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from keras.metrics import Precision, Recall
from tensorflow.keras.layers import Input, Conv2D, Dropout, MaxPooling2D, Flatten, Dense

# %%
# CodeGrade Tag Init1
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1. Data Processing
#
# Warning: running the following cell can take some time.

# %%
# CodeGrade Tag Init2
# Do not edit, remove, or copy this cell

# This code will copy the images from your google drive into the colab file
# storage. Make sure the dataset is unzipped in your drive folder.
! mkdir /tmp/Multimodal_IMDB_dataset
! rsync -ah --info=progress2 /content/drive/MyDrive/Multimodal_IMDB_dataset/Images /tmp/Multimodal_IMDB_dataset/
# Out:
#         191.88M 100%    1.24MB/s    0:02:27 (xfr#7906, to-chk=0/7907)

# %%
# CodeGrade Tag Init3
# Do not edit, remove, or copy this cell

# Load the csv with the sample IDs and genres
csv_loc = "/content/drive/MyDrive/Multimodal_IMDB_dataset/IMDB_overview_genres.csv"
dataset = pd.read_csv(csv_loc)

# Split the dataset into training and testing
data_train, data_test = model_selection.train_test_split(dataset, test_size=0.2)

# Convert the labels to arrays
labels_train = np.array(data_train.drop(['Id', 'Genre', 'Overview'],axis=1)).astype('float32')
labels_test = np.array(data_test.drop(['Id', 'Genre', 'Overview'],axis=1)).astype('float32')

# List of the genre names
genres = np.array(data_train.drop(['Id', 'Genre', 'Overview'],axis=1).columns)

# List of overviews
overviews_train = np.array(data_train['Overview'])
overviews_test = np.array(data_test['Overview'])

# Build the file locations for the images
img_loc = "/tmp/Multimodal_IMDB_dataset/Images"

img_locs_train = np.array([[img_loc + '/' + id + '.jpg' for id in data_train['Id']]])
img_locs_test = [[img_loc + '/' + id + '.jpg' for id in data_test['Id']]]

# This function is provided to read in the image files from the folder
def parse_image(filename, label):
  image = tf.io.read_file(filename)
  image = tf.io.decode_jpeg(image)
  return image, label

# %% [markdown]
# ### 1.a. Image processing of the posters

# %%
# CodeGrade Tag Init4
# Do not edit, remove, or copy this cell

# Create the initial datasets of film posters
list_posters_train_ds = tf.data.Dataset.from_tensor_slices((img_locs_train[0], labels_train))
list_posters_valid_ds = tf.data.Dataset.from_tensor_slices((img_locs_test[0], labels_test))

# %% [markdown]
# * Create a function called ```img_process``` that converts the images to float32 datatype and resizes them to 64x64 pixels

# %%
# CodeGrade Tag Ex1a-i
### Create a function called img_process that converts the images to
### float32 datatype and resizes them to 64x64 pixels

def img_process(image, label):


    #Complete here
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    image = tf.image.resize(image, [64, 64])

    return image, label

# %% [markdown]
# * **Using the ``tf.data`` API, load in the training and validation data for the posters. Be mindful of efficient data processing good practice to minimise the time it takes to load the data.**

# %%
# CodeGrade Tag Ex1a-ii
### Use the parse_image and img_process functions to construct the training and
### validation datasets. You should utilise good practice in optimising the
### dataset loading. Use a batch size of 64.

batch_size = 64

posters_train_ds = (list_posters_train_ds
    .map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)  # Parse the image files
    .batch(batch_size)  # Batch the data before processing
    .map(img_process, num_parallel_calls=tf.data.AUTOTUNE)  # Apply batch processing
    .cache()  # Cache the dataset
    .shuffle(buffer_size=1000)  # Shuffle for training
    .prefetch(tf.data.AUTOTUNE)  # Prefetch for efficient data loading
)

posters_valid_ds = (list_posters_valid_ds
    .map(parse_image, num_parallel_calls=tf.data.AUTOTUNE)  # Parse the image files
    .batch(batch_size)  # Batch the data before processing
    .map(img_process, num_parallel_calls=tf.data.AUTOTUNE)  # Apply batch processing
    .cache()  # Cache the dataset
    .prefetch(tf.data.AUTOTUNE)  # Prefetch for efficient data loading
)

# %% [markdown]
# ### 1.b. Natural Language processing of the overviews

# %%
# CodeGrade Tag Init5
# Do not edit, remove, or copy this cell

# Create the initial datasets of the film overviews
list_overviews_train_ds = tf.data.Dataset.from_tensor_slices((overviews_train, labels_train))
list_overviews_valid_ds = tf.data.Dataset.from_tensor_slices((overviews_test, labels_test))

# %% [markdown]
# * **Using the ``tf.data`` API, load in the training and validation data for the overviews.**

# %%
# CodeGrade Tag Ex1b-i
### Construct the training and validation datasets. Use a batch size of 64.

overviews_train_ds = list_overviews_train_ds.batch(64).prefetch(tf.data.AUTOTUNE)#Complete here

overviews_valid_ds = list_overviews_valid_ds.batch(64).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# * Build the vocabulary of the model by calling the ``encoder.adapt()`` method on the film overviews train data.

# %%
# CodeGrade Tag Ex1b-ii
### Build the vocabulary of the model by calling the encoder.adapt() method on
### the film overviews train data.

VOCAB_SIZE = 10000

encoder = tf.keras.layers.TextVectorization(
    max_tokens=VOCAB_SIZE)

encoder.adapt(overviews_train_ds.map(lambda text, label: text))

# %% [markdown]
# * Print the first 200 words of the vocabulary you obtained.

# %%
# CodeGrade Tag Ex1b-iii
### Print the first 200 words of the vocabulary you obtained.
vocab = np.array(encoder.get_vocabulary())
print(vocab[:200])
# Out:
# ['' '[UNK]' 'a' 'the' 'to' 'of' 'and' 'in' 'his' 'is' 'an' 'with' 'her'
#  'for' 'on' 'he' 'their' 'who' 'by' 'from' 'when' 'as' 'that' 'after'
#  'young' 'life' 'they' 'man' 'at' 'him' 'but' 'two' 'new' 'are' 'into'
#  'has' 'she' 'up' 'woman' 'family' 'out' 'love' 'one' 'find' 'must' 'be'
#  'it' 'friends' 'finds' 'story' 'school' 'world' 'them' 'while' 'where'
#  'about' 'group' 'have' 'years' 'father' 'girl' 'lives' 'city' 'town'
#  'three' 'home' 'wife' 'help' 'get' 'becomes' 'war' 'back' 'during' 'all'
#  'himself' 'boy' 'york' 'time' 'son' 'between' 'which' 'team' 'high'
#  'murder' 'gets' 'only' 'american' 'own' 'being' 'against' 'takes'
#  'police' 'down' 'daughter' 'tries' 'former' 'friend' 'its' 'become'
#  'other' 'falls' 'small' 'order' 'college' 'this' 'can' 'before' 'will'
#  'take' 'save' 'mother' 'set' 'was' 'death' 'way' 'old' 'agent' 'people'
#  'through' 'first' 'over' 'not' 'together' 'off' 'couple' 'meets'
#  'husband' 'returns' 'go' 'relationship' 'goes' 'brother' 'more' 'killer'
#  'each' 'mysterious' 'been' 'stop' 'job' 'discovers' 'living' 'make' 'day'
#  'what' 'hes' 'work' 'drug' 'best' 'four' 'forced' 'secret' 'local' 'us'
#  'past' 'begins' 'evil' 'married' 'detective' 'house' 'comes' 'parents'
#  'just' 'cop' 'now' 'men' 'film' 'discover' 'soon' 'or' 'whose' 'trying'
#  'sent' 'student' 'earth' 'sister' 'crime' 'teenage' 'women' 'series'
#  'true' 'movie' 'last' 'children' 'black' 'try' 'than' 'prison' 'brothers'
#  'battle' 'turns' 'killed' 'come' 'another' 'so' 'run' 'officer' 'most'
#  'live' 'teenager' 'herself']

# %% [markdown]
# # 2. Definition of the models
#
# ### 2.a. CNN
#
# **Using the Keras Functional API, create a convolutional neural network with the architecture shown in the model summary below.**
#
# **A few important points to consider:**
#
# * Call the convolutional layers and the first dense layer should have ReLU activation functions. The output layer should have a Sigmoid activation function.
# * Pay attention to the output shapes and the number of partmeters for each layer, as these give indications as to the correct settings for the number of filters, kernel size, stride length and padding.
# * Use the layer names provided in the summary in your model.
# * For the dropout layers, use a dropout rate of 0.2 after the convolutional layers and 0.5 after the dense layers.

# %% [markdown]
# ```
# # Model Summary
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 64, 64, 3)]       0
#
#  Conv0 (Conv2D)              (None, 32, 32, 16)        448
#
#  Drop1 (Dropout)             (None, 32, 32, 16)        0
#
#  Conv1 (Conv2D)              (None, 32, 32, 32)        4640
#
#  Conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  Drop2 (Dropout)             (None, 32, 32, 32)        0
#
#  Pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  Conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  Conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  Drop3 (Dropout)             (None, 16, 16, 64)        0
#
#  Pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  Conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  Conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  Drop4 (Dropout)             (None, 8, 8, 128)         0
#
#  Pool3 (MaxPooling2D)        (None, 4, 4, 128)         0
#
#  Flat (Flatten)              (None, 2048)              0
#
#  FC1 (Dense)                 (None, 1024)              2098176
#
#  Drop5 (Dropout)             (None, 1024)              0
#
#  FC2 (Dense)                 (None, 1024)              1049600
#
#  Drop6 (Dropout)             (None, 1024)              0
#
#  Output (Dense)              (None, 25)                25625
#
# =================================================================
# Total params: 3464601 (13.22 MB)
# Trainable params: 3464601 (13.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
#
# ```

# %%
# CodeGrade Tag Ex2a-i
### Define the model using the Keras Functional API. Use the summary above as a
### guide for the model parameters. You will need to define the filters/units of
### the layers correctly, as well as the kernel size, stride length and padding
### of the convolutional layers.

def build_cnn_model():
    input_tensor = Input(shape=(64, 64, 3), name='Input')

    x = Conv2D(filters=16, kernel_size=3, strides=2, padding='same', activation='relu', name='Conv0')(input_tensor)
    x = Dropout(0.2, name='Drop1')(x)
    x = Conv2D(filters=32, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv1')(x)
    x = Conv2D(filters=32, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv2')(x)
    x = Dropout(0.2, name='Drop2')(x)
    x = MaxPooling2D(pool_size=2, name='Pool1')(x)
    x = Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv3')(x)
    x = Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv4')(x)
    x = Dropout(0.2, name='Drop3')(x)
    x = MaxPooling2D(pool_size=2, name='Pool2')(x)
    x = Conv2D(filters=128, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv5')(x)
    x = Conv2D(filters=128, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv6')(x)
    x = Dropout(0.2, name='Drop4')(x)
    x = MaxPooling2D(pool_size=2, name='Pool3')(x)
    x = Flatten(name='Flat')(x)
    x = Dense(units=1024, activation='relu', name='FC1')(x)
    x = Dropout(0.5, name='Drop5')(x)
    x = Dense(units=1024, activation='relu', name='FC2')(x)
    x = Dropout(0.5, name='Drop6')(x)
    output_tensor = Dense(units=25, activation='sigmoid', name='Output')(x)

    model = Model(inputs=input_tensor, outputs=output_tensor)

    return model

cnn_model = build_cnn_model()

# %% [markdown]
# * Print the model summary and confirm it has the same architecture as the one provided.

# %%
# CodeGrade Tag Ex2a-ii
### Print the model summary and confirm it has the same architecture as the one
### provided.
cnn_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)                   │ (None, 64, 64, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv0 (Conv2D)                       │ (None, 32, 32, 16)          │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop1 (Dropout)                      │ (None, 32, 32, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv1 (Conv2D)                       │ (None, 32, 32, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv2 (Conv2D)                       │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop2 (Dropout)                      │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Pool1 (MaxPooling2D)                 │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv3 (Conv2D)                       │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv4 (Conv2D)                       │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop3 (Dropout)                      │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Pool2 (MaxPooling2D)                 │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv5 (Conv2D)                       │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Conv6 (Conv2D)                       │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop4 (Dropout)                      │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Pool3 (MaxPooling2D)                 │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Flat (Flatten)                       │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ FC1 (Dense)                          │ (None, 1024)                │       2,098,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop5 (Dropout)                      │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ FC2 (Dense)                          │ (None, 1024)                │       1,049,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Drop6 (Dropout)                      │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Output (Dense)                       │ (None, 25)                  │          25,625 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,464,601 (13.22 MB)
#  Trainable params: 3,464,601 (13.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * **Compile the model using the Adam Optimizer with a learning rate of ```1e-4``` and ```binary crossentropy``` loss function. For the metrics, use the ``Precision`` and ``Recall`` functions.**

# %%
# CodeGrade Tag Ex2a-iii
### Compile the model using the Adam Optimizer with a learning rate of 1e-4 and
### binary crossentropy loss function. For the metrics, use the Precision and
### Recall functions.

cnn_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=[Precision(), Recall()]
    )

# %% [markdown]
# ### 2.b. LSTM model
#
# * Set up the embedding layer by using ```tf.keras.layers.Embedding```. The ```input_dim``` is the length of the vocab, and the ```output_dim``` must be **265**. You should also set ```mask_zero=True```.

# %%
# CodeGrade Tag Ex2b-i
### Set up the embedding layer. The input_dim is the length of the vocab, and
### the output_dim must be 256. You should also set mask_zero=True.

embedder = tf.keras.layers.Embedding(input_dim=VOCAB_SIZE, output_dim=256, mask_zero=True)

# %% [markdown]
# * Use ```tf.keras.Sequential``` to build a keras sequential model, with the following layers:
#
#
#
#   1.   encoder
#   2.   embedder
#   3.   biLSTM layer with 256 units, dropout 0.5, recurrent dropout 0.2 (make sure to use the right ```return_sequences``` parametre to be able to stack this layer with the following BiLSTM)
#   4.   biLSTM layer with 128 units, dropout 0.5, recurrent dropout 0.2
#   5.   dense layer with 128 units and relu activation function
#   6.   dropout with rate 0.8
#   7.   dense output layer with 25 units and sigmoid activation function

# %%
# CodeGrade Tag Ex2b-ii
### Build a keras sequential model, with the layers provided above.

lstm_model = tf.keras.Sequential([
    encoder,
    embedder,
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(256, dropout=0.5, recurrent_dropout=0.2, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, dropout=0.5, recurrent_dropout=0.2)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.8),
    tf.keras.layers.Dense(25, activation='sigmoid')
])

lstm_model.build((None,))

# %% [markdown]
# * Print the model summary and confirm is has the same architecture as the outline provided above.

# %%
# CodeGrade Tag Ex2b-iii
### Print the model summary and confirm is has the same architecture as the
### outline provided above.

lstm_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ text_vectorization                   │ (None, None)                │               0 │
# │ (TextVectorization)                  │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding (Embedding)                │ (None, None, 256)           │       2,560,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, None, 512)           │       1,050,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 256)                 │         656,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 25)                  │           3,225 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,303,129 (16.42 MB)
#  Trainable params: 4,303,129 (16.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * Compile the model with binary crossentropy loss and the adam optimizer. For the metrics, use the Precision and Recall functions.

# %%
# CodeGrade Tag Ex2b-iv
### Compile the model with binary crossentropy loss, the adam optimizer, with
### the precision and recall metrics

lstm_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=[Precision(), Recall()]
    )

# %% [markdown]
# # 3. Training of the models
#
# * **For each model, create a Checkpoint Callback that saves the weights of the best performing epoch, based on the validation loss.**

# %%
# CodeGrade Tag Ex3a-i
### Create two ModelCheckpoint callbacks to store the bext weights from each
### model, both based on the validation loss.

checkpoint_cnn_filepath = '/content/checkpoint_cnn.weights.h5'
checkpoint_lstm_filepath = '/content/checkpoint_lstm.weights.h5'

from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_cnn_callback = ModelCheckpoint(
    filepath=checkpoint_cnn_filepath,
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

checkpoint_lstm_callback = ModelCheckpoint(
    filepath=checkpoint_lstm_filepath,
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

# %% [markdown]
# * **Create a Learning Rate Scheduler Callback that utilises the provided function to decrease the learning rate during training.**

# %%
# CodeGrade Tag Ex3a-ii
### Using the function provided, create a LearningRateScheduler callback, call
### it "lr_callback"

def scheduler(epoch, lr):
    if epoch < 10:
        return float(lr)
    else:
        return float(lr * tf.math.exp(-0.01))

lr_callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %% [markdown]
# ### 3.a. CNN training
#
# * **Train the CNN model for 40 epochs, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3a-iii
### Train the model for 40 epochs, using the callbacks you have created. Store
### the losses and metrics in a history object.

cnn_history = cnn_model.fit(
    posters_train_ds,
    validation_data=posters_valid_ds,
    epochs=40,
    callbacks=[checkpoint_cnn_callback, lr_callback]
    )
# Out:
# Epoch 1/40
# 75/80 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.4786 - precision: 0.2491 - recall: 0.2796
# Epoch 1: val_loss improved from inf to 0.30155, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 29s 168ms/step - loss: 0.4687 - precision: 0.2557 - recall: 0.2767 - val_loss: 0.3015 - val_precision: 0.5238 - val_recall: 0.0036 - learning_rate: 1.0000e-04
# Epoch 2/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2537 - precision: 0.4860 - recall: 0.2193
# Epoch 2: val_loss did not improve from 0.30155
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - loss: 0.2536 - precision: 0.4859 - recall: 0.2191 - val_loss: 0.3018 - val_precision: 0.5447 - val_recall: 0.2283 - learning_rate: 1.0000e-04
# Epoch 3/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2462 - precision: 0.4932 - recall: 0.2140
# Epoch 3: val_loss improved from 0.30155 to 0.28666, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2462 - precision: 0.4933 - recall: 0.2139 - val_loss: 0.2867 - val_precision: 0.5447 - val_recall: 0.2283 - learning_rate: 1.0000e-04
# Epoch 4/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2439 - precision: 0.4986 - recall: 0.2093
# Epoch 4: val_loss improved from 0.28666 to 0.26712, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2439 - precision: 0.4987 - recall: 0.2093 - val_loss: 0.2671 - val_precision: 0.5447 - val_recall: 0.2283 - learning_rate: 1.0000e-04
# Epoch 5/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2408 - precision: 0.5370 - recall: 0.2171
# Epoch 5: val_loss did not improve from 0.26712
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2407 - precision: 0.5372 - recall: 0.2173 - val_loss: 0.2679 - val_precision: 0.6223 - val_recall: 0.1551 - learning_rate: 1.0000e-04
# Epoch 6/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2340 - precision: 0.5875 - recall: 0.2707
# Epoch 6: val_loss improved from 0.26712 to 0.25955, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2340 - precision: 0.5874 - recall: 0.2707 - val_loss: 0.2596 - val_precision: 0.5825 - val_recall: 0.2926 - learning_rate: 1.0000e-04
# Epoch 7/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2333 - precision: 0.5830 - recall: 0.2585
# Epoch 7: val_loss improved from 0.25955 to 0.25452, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2333 - precision: 0.5829 - recall: 0.2587 - val_loss: 0.2545 - val_precision: 0.5721 - val_recall: 0.2707 - learning_rate: 1.0000e-04
# Epoch 8/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2306 - precision: 0.5786 - recall: 0.2678
# Epoch 8: val_loss did not improve from 0.25452
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2306 - precision: 0.5788 - recall: 0.2678 - val_loss: 0.2690 - val_precision: 0.5701 - val_recall: 0.2641 - learning_rate: 1.0000e-04
# Epoch 9/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2303 - precision: 0.5863 - recall: 0.2798
# Epoch 9: val_loss did not improve from 0.25452
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2303 - precision: 0.5863 - recall: 0.2797 - val_loss: 0.2627 - val_precision: 0.5493 - val_recall: 0.2309 - learning_rate: 1.0000e-04
# Epoch 10/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2307 - precision: 0.5754 - recall: 0.2646
# Epoch 10: val_loss improved from 0.25452 to 0.24771, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2307 - precision: 0.5755 - recall: 0.2647 - val_loss: 0.2477 - val_precision: 0.5590 - val_recall: 0.2465 - learning_rate: 1.0000e-04
# Epoch 11/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2289 - precision: 0.5973 - recall: 0.2883
# Epoch 11: val_loss did not improve from 0.24771
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2289 - precision: 0.5973 - recall: 0.2882 - val_loss: 0.2509 - val_precision: 0.6170 - val_recall: 0.3032 - learning_rate: 9.9005e-05
# Epoch 12/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2281 - precision: 0.5904 - recall: 0.2665
# Epoch 12: val_loss did not improve from 0.24771
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2280 - precision: 0.5912 - recall: 0.2673 - val_loss: 0.2538 - val_precision: 0.5532 - val_recall: 0.2359 - learning_rate: 9.8020e-05
# Epoch 13/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2251 - precision: 0.6151 - recall: 0.2740
# Epoch 13: val_loss did not improve from 0.24771
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2252 - precision: 0.6152 - recall: 0.2741 - val_loss: 0.2523 - val_precision: 0.5650 - val_recall: 0.2478 - learning_rate: 9.7045e-05
# Epoch 14/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2243 - precision: 0.6169 - recall: 0.2763
# Epoch 14: val_loss did not improve from 0.24771
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2243 - precision: 0.6175 - recall: 0.2763 - val_loss: 0.2544 - val_precision: 0.5756 - val_recall: 0.2548 - learning_rate: 9.6079e-05
# Epoch 15/40
# 75/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2245 - precision: 0.6205 - recall: 0.2798
# Epoch 15: val_loss improved from 0.24771 to 0.24655, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2245 - precision: 0.6209 - recall: 0.2798 - val_loss: 0.2465 - val_precision: 0.5806 - val_recall: 0.2614 - learning_rate: 9.5123e-05
# Epoch 16/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2241 - precision: 0.6320 - recall: 0.2726
# Epoch 16: val_loss did not improve from 0.24655
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2241 - precision: 0.6319 - recall: 0.2726 - val_loss: 0.2482 - val_precision: 0.5639 - val_recall: 0.2399 - learning_rate: 9.4176e-05
# Epoch 17/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2228 - precision: 0.6364 - recall: 0.2763
# Epoch 17: val_loss did not improve from 0.24655
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2228 - precision: 0.6363 - recall: 0.2763 - val_loss: 0.2466 - val_precision: 0.5798 - val_recall: 0.2515 - learning_rate: 9.3239e-05
# Epoch 18/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2212 - precision: 0.6368 - recall: 0.2885
# Epoch 18: val_loss did not improve from 0.24655
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2212 - precision: 0.6368 - recall: 0.2883 - val_loss: 0.2473 - val_precision: 0.6011 - val_recall: 0.2551 - learning_rate: 9.2312e-05
# Epoch 19/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2221 - precision: 0.6364 - recall: 0.2758
# Epoch 19: val_loss improved from 0.24655 to 0.24519, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2221 - precision: 0.6364 - recall: 0.2758 - val_loss: 0.2452 - val_precision: 0.5961 - val_recall: 0.2631 - learning_rate: 9.1393e-05
# Epoch 20/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2201 - precision: 0.6439 - recall: 0.2885
# Epoch 20: val_loss improved from 0.24519 to 0.24105, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2201 - precision: 0.6439 - recall: 0.2883 - val_loss: 0.2410 - val_precision: 0.6043 - val_recall: 0.2717 - learning_rate: 9.0484e-05
# Epoch 21/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2206 - precision: 0.6424 - recall: 0.2889
# Epoch 21: val_loss did not improve from 0.24105
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2206 - precision: 0.6424 - recall: 0.2888 - val_loss: 0.2449 - val_precision: 0.6137 - val_recall: 0.2021 - learning_rate: 8.9583e-05
# Epoch 22/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2199 - precision: 0.6496 - recall: 0.2764
# Epoch 22: val_loss did not improve from 0.24105
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2199 - precision: 0.6495 - recall: 0.2764 - val_loss: 0.2420 - val_precision: 0.5961 - val_recall: 0.2406 - learning_rate: 8.8692e-05
# Epoch 23/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2217 - precision: 0.6521 - recall: 0.2668
# Epoch 23: val_loss did not improve from 0.24105
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2217 - precision: 0.6520 - recall: 0.2670 - val_loss: 0.2471 - val_precision: 0.6111 - val_recall: 0.2369 - learning_rate: 8.7810e-05
# Epoch 24/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2208 - precision: 0.6461 - recall: 0.2662
# Epoch 24: val_loss improved from 0.24105 to 0.23591, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2208 - precision: 0.6462 - recall: 0.2665 - val_loss: 0.2359 - val_precision: 0.6208 - val_recall: 0.2724 - learning_rate: 8.6936e-05
# Epoch 25/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2205 - precision: 0.6497 - recall: 0.2761
# Epoch 25: val_loss did not improve from 0.23591
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2204 - precision: 0.6496 - recall: 0.2762 - val_loss: 0.2375 - val_precision: 0.6314 - val_recall: 0.2707 - learning_rate: 8.6071e-05
# Epoch 26/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2209 - precision: 0.6525 - recall: 0.2734
# Epoch 26: val_loss did not improve from 0.23591
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2208 - precision: 0.6525 - recall: 0.2736 - val_loss: 0.2423 - val_precision: 0.5915 - val_recall: 0.2432 - learning_rate: 8.5214e-05
# Epoch 27/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2184 - precision: 0.6566 - recall: 0.2807
# Epoch 27: val_loss improved from 0.23591 to 0.23400, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2184 - precision: 0.6563 - recall: 0.2807 - val_loss: 0.2340 - val_precision: 0.6283 - val_recall: 0.2571 - learning_rate: 8.4366e-05
# Epoch 28/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2188 - precision: 0.6595 - recall: 0.2813
# Epoch 28: val_loss did not improve from 0.23400
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2188 - precision: 0.6595 - recall: 0.2814 - val_loss: 0.2344 - val_precision: 0.6437 - val_recall: 0.2664 - learning_rate: 8.3527e-05
# Epoch 29/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2190 - precision: 0.6416 - recall: 0.2664
# Epoch 29: val_loss did not improve from 0.23400
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2190 - precision: 0.6418 - recall: 0.2665 - val_loss: 0.2349 - val_precision: 0.6280 - val_recall: 0.2724 - learning_rate: 8.2696e-05
# Epoch 30/40
# 78/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2175 - precision: 0.6520 - recall: 0.2804
# Epoch 30: val_loss improved from 0.23400 to 0.23345, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2174 - precision: 0.6522 - recall: 0.2804 - val_loss: 0.2334 - val_precision: 0.6362 - val_recall: 0.2810 - learning_rate: 8.1873e-05
# Epoch 31/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2149 - precision: 0.6573 - recall: 0.2860
# Epoch 31: val_loss did not improve from 0.23345
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2150 - precision: 0.6573 - recall: 0.2859 - val_loss: 0.2387 - val_precision: 0.6220 - val_recall: 0.2644 - learning_rate: 8.1058e-05
# Epoch 32/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2154 - precision: 0.6607 - recall: 0.2932
# Epoch 32: val_loss improved from 0.23345 to 0.23127, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2154 - precision: 0.6606 - recall: 0.2931 - val_loss: 0.2313 - val_precision: 0.6345 - val_recall: 0.2508 - learning_rate: 8.0252e-05
# Epoch 33/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2164 - precision: 0.6626 - recall: 0.2816
# Epoch 33: val_loss did not improve from 0.23127
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2164 - precision: 0.6627 - recall: 0.2817 - val_loss: 0.2360 - val_precision: 0.6460 - val_recall: 0.2661 - learning_rate: 7.9453e-05
# Epoch 34/40
# 79/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2180 - precision: 0.6565 - recall: 0.2826
# Epoch 34: val_loss did not improve from 0.23127
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2179 - precision: 0.6567 - recall: 0.2827 - val_loss: 0.2347 - val_precision: 0.6396 - val_recall: 0.2535 - learning_rate: 7.8663e-05
# Epoch 35/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2139 - precision: 0.6753 - recall: 0.2854
# Epoch 35: val_loss did not improve from 0.23127
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2139 - precision: 0.6753 - recall: 0.2853 - val_loss: 0.2354 - val_precision: 0.6234 - val_recall: 0.2435 - learning_rate: 7.7880e-05
# Epoch 36/40
# 76/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2178 - precision: 0.6654 - recall: 0.2750
# Epoch 36: val_loss did not improve from 0.23127
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2177 - precision: 0.6654 - recall: 0.2755 - val_loss: 0.2335 - val_precision: 0.6366 - val_recall: 0.2641 - learning_rate: 7.7105e-05
# Epoch 37/40
# 77/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2142 - precision: 0.6651 - recall: 0.2944
# Epoch 37: val_loss did not improve from 0.23127
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2142 - precision: 0.6651 - recall: 0.2940 - val_loss: 0.2346 - val_precision: 0.6272 - val_recall: 0.2671 - learning_rate: 7.6338e-05
# Epoch 38/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2140 - precision: 0.6756 - recall: 0.2854
# Epoch 38: val_loss did not improve from 0.23127
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2140 - precision: 0.6756 - recall: 0.2854 - val_loss: 0.2351 - val_precision: 0.6819 - val_recall: 0.2528 - learning_rate: 7.5578e-05
# Epoch 39/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2104 - precision: 0.6784 - recall: 0.2968
# Epoch 39: val_loss did not improve from 0.23127
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2104 - precision: 0.6783 - recall: 0.2968 - val_loss: 0.2335 - val_precision: 0.6824 - val_recall: 0.2392 - learning_rate: 7.4826e-05
# Epoch 40/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2139 - precision: 0.6780 - recall: 0.2773
# Epoch 40: val_loss did not improve from 0.23127
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2139 - precision: 0.6780 - recall: 0.2774 - val_loss: 0.2331 - val_precision: 0.6783 - val_recall: 0.2697 - learning_rate: 7.4082e-05

# %% [markdown]
# * **Train the model for 20 epochs** (this may take several minutes)**, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3b-i
# Train the model for 20 epochs.
lstm_history = lstm_model.fit(
                    #Complete here
                    overviews_train_ds,
                    validation_data=overviews_valid_ds,
                    epochs=20,
                    callbacks=[checkpoint_lstm_callback, lr_callback]
                    )
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - loss: 0.6696 - precision_1: 0.1123 - recall_1: 0.4325
# Epoch 1: val_loss improved from inf to 0.36595, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 54s 504ms/step - loss: 0.6689 - precision_1: 0.1125 - recall_1: 0.4320 - val_loss: 0.3660 - val_precision_1: 0.5188 - val_recall_1: 0.3115 - learning_rate: 1.0000e-04
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - loss: 0.4699 - precision_1: 0.1705 - recall_1: 0.3123
# Epoch 2: val_loss improved from 0.36595 to 0.29778, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 76s 507ms/step - loss: 0.4697 - precision_1: 0.1706 - recall_1: 0.3122 - val_loss: 0.2978 - val_precision_1: 0.5440 - val_recall_1: 0.2293 - learning_rate: 1.0000e-04
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - loss: 0.4185 - precision_1: 0.2052 - recall_1: 0.2838
# Epoch 3: val_loss improved from 0.29778 to 0.27521, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 40s 498ms/step - loss: 0.4184 - precision_1: 0.2052 - recall_1: 0.2837 - val_loss: 0.2752 - val_precision_1: 0.5447 - val_recall_1: 0.2283 - learning_rate: 1.0000e-04
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - loss: 0.3833 - precision_1: 0.2359 - recall_1: 0.2689
# Epoch 4: val_loss improved from 0.27521 to 0.26143, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 41s 513ms/step - loss: 0.3832 - precision_1: 0.2359 - recall_1: 0.2688 - val_loss: 0.2614 - val_precision_1: 0.5447 - val_recall_1: 0.2283 - learning_rate: 1.0000e-04
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - loss: 0.3579 - precision_1: 0.2697 - recall_1: 0.2661
# Epoch 5: val_loss improved from 0.26143 to 0.25569, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 41s 513ms/step - loss: 0.3579 - precision_1: 0.2697 - recall_1: 0.2659 - val_loss: 0.2557 - val_precision_1: 0.5447 - val_recall_1: 0.2283 - learning_rate: 1.0000e-04
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - loss: 0.3416 - precision_1: 0.2945 - recall_1: 0.2486
# Epoch 6: val_loss improved from 0.25569 to 0.25019, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 43s 543ms/step - loss: 0.3415 - precision_1: 0.2946 - recall_1: 0.2486 - val_loss: 0.2502 - val_precision_1: 0.5447 - val_recall_1: 0.2283 - learning_rate: 1.0000e-04
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - loss: 0.3311 - precision_1: 0.3112 - recall_1: 0.2394
# Epoch 7: val_loss improved from 0.25019 to 0.24733, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 79s 511ms/step - loss: 0.3311 - precision_1: 0.3113 - recall_1: 0.2393 - val_loss: 0.2473 - val_precision_1: 0.5447 - val_recall_1: 0.2283 - learning_rate: 1.0000e-04
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - loss: 0.3219 - precision_1: 0.3317 - recall_1: 0.2270
# Epoch 8: val_loss improved from 0.24733 to 0.24587, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 41s 510ms/step - loss: 0.3219 - precision_1: 0.3318 - recall_1: 0.2270 - val_loss: 0.2459 - val_precision_1: 0.5447 - val_recall_1: 0.2283 - learning_rate: 1.0000e-04
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - loss: 0.3102 - precision_1: 0.3597 - recall_1: 0.2256
# Epoch 9: val_loss improved from 0.24587 to 0.24388, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 40s 499ms/step - loss: 0.3102 - precision_1: 0.3597 - recall_1: 0.2256 - val_loss: 0.2439 - val_precision_1: 0.5447 - val_recall_1: 0.2283 - learning_rate: 1.0000e-04
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step - loss: 0.3061 - precision_1: 0.3657 - recall_1: 0.2208
# Epoch 10: val_loss improved from 0.24388 to 0.24261, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 42s 507ms/step - loss: 0.3061 - precision_1: 0.3658 - recall_1: 0.2208 - val_loss: 0.2426 - val_precision_1: 0.5447 - val_recall_1: 0.2283 - learning_rate: 1.0000e-04
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - loss: 0.3002 - precision_1: 0.3878 - recall_1: 0.2252
# Epoch 11: val_loss improved from 0.24261 to 0.24165, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 40s 494ms/step - loss: 0.3002 - precision_1: 0.3878 - recall_1: 0.2252 - val_loss: 0.2416 - val_precision_1: 0.5447 - val_recall_1: 0.2283 - learning_rate: 9.9005e-05
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - loss: 0.2927 - precision_1: 0.3904 - recall_1: 0.2158
# Epoch 12: val_loss improved from 0.24165 to 0.24068, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 40s 502ms/step - loss: 0.2928 - precision_1: 0.3905 - recall_1: 0.2158 - val_loss: 0.2407 - val_precision_1: 0.5447 - val_recall_1: 0.2283 - learning_rate: 9.8020e-05
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - loss: 0.2899 - precision_1: 0.4127 - recall_1: 0.2138
# Epoch 13: val_loss improved from 0.24068 to 0.23994, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 41s 506ms/step - loss: 0.2899 - precision_1: 0.4127 - recall_1: 0.2138 - val_loss: 0.2399 - val_precision_1: 0.5447 - val_recall_1: 0.2280 - learning_rate: 9.7045e-05
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - loss: 0.2854 - precision_1: 0.4298 - recall_1: 0.2249
# Epoch 14: val_loss improved from 0.23994 to 0.23744, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 41s 519ms/step - loss: 0.2854 - precision_1: 0.4297 - recall_1: 0.2248 - val_loss: 0.2374 - val_precision_1: 0.5493 - val_recall_1: 0.2253 - learning_rate: 9.6079e-05
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - loss: 0.2813 - precision_1: 0.4374 - recall_1: 0.2256
# Epoch 15: val_loss improved from 0.23744 to 0.23418, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 515ms/step - loss: 0.2812 - precision_1: 0.4375 - recall_1: 0.2256 - val_loss: 0.2342 - val_precision_1: 0.5726 - val_recall_1: 0.2104 - learning_rate: 9.5123e-05
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - loss: 0.2714 - precision_1: 0.4629 - recall_1: 0.2422
# Epoch 16: val_loss improved from 0.23418 to 0.23087, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 41s 514ms/step - loss: 0.2715 - precision_1: 0.4628 - recall_1: 0.2421 - val_loss: 0.2309 - val_precision_1: 0.5812 - val_recall_1: 0.2253 - learning_rate: 9.4176e-05
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - loss: 0.2685 - precision_1: 0.4667 - recall_1: 0.2447
# Epoch 17: val_loss improved from 0.23087 to 0.22920, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 41s 510ms/step - loss: 0.2685 - precision_1: 0.4668 - recall_1: 0.2447 - val_loss: 0.2292 - val_precision_1: 0.5821 - val_recall_1: 0.2326 - learning_rate: 9.3239e-05
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step - loss: 0.2613 - precision_1: 0.4978 - recall_1: 0.2705
# Epoch 18: val_loss improved from 0.22920 to 0.22728, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 41s 516ms/step - loss: 0.2613 - precision_1: 0.4978 - recall_1: 0.2704 - val_loss: 0.2273 - val_precision_1: 0.6040 - val_recall_1: 0.2492 - learning_rate: 9.2312e-05
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - loss: 0.2598 - precision_1: 0.4968 - recall_1: 0.2635
# Epoch 19: val_loss improved from 0.22728 to 0.22601, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 41s 504ms/step - loss: 0.2598 - precision_1: 0.4969 - recall_1: 0.2635 - val_loss: 0.2260 - val_precision_1: 0.5989 - val_recall_1: 0.2608 - learning_rate: 9.1393e-05
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - loss: 0.2560 - precision_1: 0.5127 - recall_1: 0.2810
# Epoch 20: val_loss improved from 0.22601 to 0.22513, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 40s 495ms/step - loss: 0.2560 - precision_1: 0.5127 - recall_1: 0.2809 - val_loss: 0.2251 - val_precision_1: 0.6040 - val_recall_1: 0.2714 - learning_rate: 9.0484e-05

# %% [markdown]
# # 4. Evaluation of the models
#
# ### 4.a. CNN Evaluation
#
# * **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the model performance.**

# %%
# CodeGrade Tag Ex4a-i

# Get metric names from cnn_history.history
metric_names = list(cnn_history.history.keys())

# Print all keys in the history dictionary for debugging
print("History dictionary keys:", cnn_history.history.keys())

# Remove 'loss' and 'val_loss' if they are present in the list
if 'loss' in metric_names:
    metric_names.remove('loss')
if 'val_loss' in metric_names:
    metric_names.remove('val_loss')

print(f"Metric names: {metric_names}")

# Plot Training and Validation Loss
plt.figure(figsize=(12, 6))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(cnn_history.history['loss'], label='Training Loss')
plt.plot(cnn_history.history['val_loss'], label='Validation Loss')
plt.title('CNN Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# First Metric Plot (e.g., Precision)
plt.subplot(1, 2, 2)
plt.plot(cnn_history.history[metric_names[0]], label='Training Precision')
plt.plot(cnn_history.history[metric_names[2]], label='Validation Precision')
plt.title('CNN Model Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.tight_layout()
plt.show()

# Plot Second Metric (e.g., Recall)
plt.figure(figsize=(6, 6))
plt.plot(cnn_history.history[metric_names[1]], label='Training Recall')
plt.plot(cnn_history.history[metric_names[3]], label='Validation Recall')
plt.title('CNN Model Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# History dictionary keys: dict_keys(['loss', 'precision', 'recall', 'val_loss', 'val_precision', 'val_recall', 'learning_rate'])
# Metric names: ['precision', 'recall', 'val_precision', 'val_recall', 'learning_rate']

# %% [markdown]
# * **Load the best weights from your model checkpoint, and create plots demonstrating the classification performance for all three classes. Include these plots in your report, and critically evaluate on the performance of the model across the classes.**

# %% [markdown]
# ### 4.b. LSTM Evaluation
#
# * **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the model performance.**

# %%
# CodeGrade Tag Ex4b-i

# Get metric names from cnn_history.history
metric_names = list(lstm_history.history.keys())

# Print all keys in the history dictionary for debugging
print("History dictionary keys:", lstm_history.history.keys())

# Remove 'loss' and 'val_loss' if they are present in the list
if 'loss' in metric_names:
    metric_names.remove('loss')
if 'val_loss' in metric_names:
    metric_names.remove('val_loss')

print(f"Metric names: {metric_names}")

plt.figure(figsize=(12, 6))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(lstm_history.history['loss'], label='Training Loss')
plt.plot(lstm_history.history['val_loss'], label='Validation Loss')
plt.title('LSTM Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Precision plot
plt.subplot(1, 2, 2)
plt.plot(lstm_history.history[metric_names[0]], label='Training Precision')
plt.plot(lstm_history.history[metric_names[2]], label='Validation Precision')
plt.title('LSTM Model Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.tight_layout()
plt.show()

# Plot Recall
plt.figure(figsize=(6, 6))
plt.plot(lstm_history.history[metric_names[1]], label='Training Recall')
plt.plot(lstm_history.history[metric_names[3]], label='Validation Recall')
plt.title('LSTM Model Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.show()
# Out:
# History dictionary keys: dict_keys(['loss', 'precision_1', 'recall_1', 'val_loss', 'val_precision_1', 'val_recall_1', 'learning_rate'])
# Metric names: ['precision_1', 'recall_1', 'val_precision_1', 'val_recall_1', 'learning_rate']

# %% [markdown]
# ### 4.c. Produce examples for the report
#
# * First, load the best weights from your checkpoints of both your models.
#
# * Choose a few films from the dataset, plot their posters and print their overviews. Use these example films to demonstrate the classification performance of the CNN model on their posters and of the LSTM model on their overview.
#
# * Be sure to demonstrate the results of the multi-label classification. Compare, for each example film, the top three most probable genres predicted by the CNN and the top three most probable genres predicted by the LSTM with the ground truth genres.
#
# * Include these examples in your report, and critically evaluate on the performance of the model across the classes.

# %%
# CodeGrade Tag Ex4c

#Complete here
import random
cnn_model.load_weights(checkpoint_cnn_filepath)  # Load weights from checkpoint_cnn_filepath
lstm_model.load_weights(checkpoint_lstm_filepath)  # Load weights from checkpoint_lstm_filepath


# List of genres
genres = [
    "Action", "Adventure", "Animation", "Biography", "Comedy", "Crime", "Documentary", "Drama", "Family", "Fantasy",
    "History", "Horror", "Music", "Musical", "Mystery", "N/A", "News", "Reality-TV", "Romance", "Sci-Fi", "Short",
    "Sport", "Thriller", "War", "Western"
]

num_examples = 5  # Number of examples to select
example_indices = random.sample(range(len(img_locs_train[0])), num_examples)

example_posters = [img_locs_train[0][idx] for idx in example_indices]
example_overviews = [overviews_train[idx] for idx in example_indices]
example_ground_truth = [labels_train[idx] for idx in example_indices]

# Function to get top-3 predictions
def get_top_predictions(model, dataset, top_n=3):
    predictions = model.predict(dataset)  # Predict probabilities
    top_indices = predictions.argsort(axis=-1)[:, -top_n:][:, ::-1]  # Sort and get top-N indices
    top_genres = [[genres[idx] for idx in indices] for indices in top_indices]  # Map indices to genre names
    return top_genres

# Function to map ground truth binary labels to genre names
def map_ground_truth_labels(labels):
    return [[genres[i] for i, val in enumerate(label_list) if val == 1] for label_list in labels]



# Prepare datasets for predictions
# CNN requires posters
example_posters_ds = tf.data.Dataset.from_tensor_slices((example_posters, [0] * len(example_posters)))
example_posters_ds = example_posters_ds.map(parse_image).map(img_process).batch(1)

# LSTM requires text overviews
example_overviews_ds = tf.data.Dataset.from_tensor_slices((example_overviews, [0] * len(example_overviews)))
example_overviews_ds = example_overviews_ds.batch(1)

# Make predictions
cnn_predictions = get_top_predictions(cnn_model, example_posters_ds)
lstm_predictions = get_top_predictions(lstm_model, example_overviews_ds)

# Convert ground truth to genre names
example_ground_truth_names = map_ground_truth_labels(example_ground_truth)

# Visualize results
for i, idx in enumerate(example_indices):
    # Plot poster
    poster_image = plt.imread(example_posters[i])
    plt.imshow(poster_image)
    plt.title(f"Poster for Film {idx}")
    plt.axis('off')
    plt.show()

    # Print overview
    print(f"Overview for Film {idx}:\n{example_overviews[i]}")
    print("\nGround Truth Genres:", example_ground_truth_names[i])

    # Display predictions
    print("Top-3 CNN Predictions:", cnn_predictions[i])
    print("Top-3 LSTM Predictions:", lstm_predictions[i])
    print("-----")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step
# Overview for Film 1529:
# When his wife falls sick, a father finds himself having to carpool for the neighborhood school children and being taken hostage by a bank robber.
#
# Ground Truth Genres: ['Comedy']
# Top-3 CNN Predictions: ['Comedy', 'Drama', 'Romance']
# Top-3 LSTM Predictions: ['Drama', 'Comedy', 'Action']
# -----
# Overview for Film 3057:
# Nick is a district attorney investigating several deaths of AIDS sufferers in the gay community of New York City's Chelsea District. Each case suggest the use of assisted suicide, which is illegal in New York.
#
# Ground Truth Genres: ['Drama']
# Top-3 CNN Predictions: ['Drama', 'Action', 'Crime']
# Top-3 LSTM Predictions: ['Drama', 'Comedy', 'Romance']
# -----
# Overview for Film 1548:
# A mom looks for another source of income, when her husband leaves with the money meant for the new mobile home. A nearby Indian territory stretches across the border to Canada with a drivable frozen river between. Smuggling?
#
# Ground Truth Genres: ['Crime', 'Drama']
# Top-3 CNN Predictions: ['Drama', 'Action', 'Thriller']
# Top-3 LSTM Predictions: ['Drama', 'Comedy', 'Romance']
# -----
# Overview for Film 2686:
# Cody, a little girl abandoned by her mother and raised by her aunt, a nurse, is kidnapped. The girl's guardian, aided by an F.B.I. agent, learn that Cody has supernatural abilities, and the abductees are a Satanic cult willing to do anything to gain them.
#
# Ground Truth Genres: ['Crime', 'Drama', 'Horror']
# Top-3 CNN Predictions: ['Drama', 'Action', 'Thriller']
# Top-3 LSTM Predictions: ['Action', 'Drama', 'Comedy']
# -----
# Overview for Film 2898:
# The several misadventures and life-lessons learned by 8-year-old Theodore "Beaver" Cleaver in an entertaining and hilarious tale of a small-town Ohio family and the daily trials and tribunes of life.
#
# Ground Truth Genres: ['Comedy', 'Family']
# Top-3 CNN Predictions: ['Drama', 'Romance', 'Comedy']
# Top-3 LSTM Predictions: ['Drama', 'Comedy', 'Action']
# -----
